# %%
# !pip install -e /home/q039tl/openicu_ricu_converter_project
# Out:
# Obtaining file:///home/q039tl/openicu_ricu_converter_project
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for openicu-ricu-converter (pyproject.toml) ... done
#   Created wheel for openicu-ricu-converter: filename=openicu_ricu_converter-0.1.1-0.editable-py3-none-any.whl size=4507 sha256=22c15c164df467aeefbddd13ac39f9c01e521c2001cc267d4ef2f55046b821db
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mha5gk81/wheels/0e/fc/2e/ef01017957148bae036c11af039acb9c6b373f9b10bd4b60fb
# Successfully built openicu-ricu-converter
# ...
#   Attempting uninstall: openicu-ricu-converter
#     Found existing installation: openicu-ricu-converter 0.1.1
#     Uninstalling openicu-ricu-converter-0.1.1:
#       Successfully uninstalled openicu-ricu-converter-0.1.1
# ...

# %%
# !openicu-ricu-convert \
  --concept-dict /home/q039tl/ricu/inst/extdata/config/concept-dict.json \
  --source miiv eicu \
  --openicu-config /home/q039tl/OpenICU/config\
  --output-config /home/q039tl/OpenICU.example/ricu-converter-output \
  --overwrite
# Out:
# Loaded concepts: 121
# Generated YAML payloads: 266
# Unsupported/report entries: 85
# Written files: 263
# Report: /home/q039tl/OpenICU.example/ricu-converter-output/ricu_unsupported.yml
