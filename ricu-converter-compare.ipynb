# %%
# !openicu-ricu-compare-outputs \
  --old /home/q039tl/OpenICU.example/output/project/workspace/concept-cur \
  --new /home/q039tl/OpenICU.example/output/project/workspace/concept \
  --normalize-code hyphen-to-underscore \
  --report-md concept_output_diff_report.md \
  --report-json concept_output_diff_report.json
# Out:
# [added_file] C_reactive_protein/1.0.0/mimic-iv.parquet
#   - only exists in new: /home/q039tl/OpenICU.example/output/project/workspace/concept/C_reactive_protein/1.0.0/mimic-iv.parquet
# [changed] alanine_aminotransferase/1.0.0/mimic-iv.parquet
#   rows: 0 -> 1826482
#   - row count changed: 0 -> 1826482
#   - rows only in old: 0
#   - rows only in new: 1825469
# [changed] aspartate_aminotransferase/1.0.0/mimic-iv.parquet
#   rows: 0 -> 1793910
#   - row count changed: 0 -> 1793910
#   - rows only in old: 0
#   - rows only in new: 1793088
# [added_file] body_fluid_sampling/1.0.0/mimic-iv.parquet
#   - only exists in new: /home/q039tl/OpenICU.example/output/project/workspace/concept/body_fluid_sampling/1.0.0/mimic-iv.parquet
# [changed] creatine_kinase/1.0.0/mimic-iv.parquet
#   rows: 0 -> 334746
#   - row count changed: 0 -> 334746
#   - rows only in old: 0
#   - rows only in new: 334699
# [removed_file] dextrose_(as_D10)/1.0.0/mimic-iv.parquet
# ...
